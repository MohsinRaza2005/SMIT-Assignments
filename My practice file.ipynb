# %%
for i in range(10):
    print("Raja Ahsan")
# Out:
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan
# Raja Ahsan

# %%
for i in range(10):
    print(f"{i}:Mohsin Raza")
# Out:
# 0:Mohsin Raza
# 1:Mohsin Raza
# 2:Mohsin Raza
# 3:Mohsin Raza
# 4:Mohsin Raza
# 5:Mohsin Raza
# 6:Mohsin Raza
# 7:Mohsin Raza
# 8:Mohsin Raza
# 9:Mohsin Raza

# %%
student_name = ["Ubaid","sameer","Wasiq","shahmeer","sahil","daniyal","Ebad","Ibrahim"]
for i in range(8):
    print(f"{i+1}:{student_name[i]}")
# Out:
# 1:Ubaid
# 2:sameer
# 3:Wasiq
# 4:shahmeer
# 5:sahil
# 6:daniyal
# 7:Ebad
# 8:Ibrahim

# %%
"ibrahim" * 5 +" "
# Out:
# 'ibrahimibrahimibrahimibrahimibrahim '

# %%
8//2
# Out:
# 4
